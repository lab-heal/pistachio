# %% [markdown]
# TODO
#
# -   weekly performance, only show best model, weeks 0 to 20
# -   run variations of prediction window (lookahead) + frequency, plot of sensitivity by frequency/lookahead
# -   sensitivity + specificity + AUC+ROC
# -   do weekly versions + trendline, not cum
# -   for manuscript -- use terms e.g., "scheduled retraining", "closed loop"
# -   why even do online learning -- capture "in situ" context, don't simply apply historical model to new cohort
# -   experiment with oversampling recent data (or sample weighting, focus on the positive observations)
#     -   look into regret minimization algos

# %%
from pathlib import Path

import numpy as np
import pandas as pd

DATA_DIR = Path("./pistachio_1_data")
dyads_df = pd.read_csv(DATA_DIR / "all_dyads.csv")
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/2033846779.py:7: DtypeWarning: Columns (47,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   dyads_df = pd.read_csv(DATA_DIR / "all_dyads.csv")

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    df["therapy_length_days"] = (
        pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])
    ).dt.days

    # df["sin_day_of_week"] = np.sin(
    #     2 * np.pi * pd.to_datetime(df["ActivityDateTime"]).dt.dayofweek / 7
    # )
    # df["cos_day_of_week"] = np.cos(
    #     2 * np.pi * pd.to_datetime(df["ActivityDateTime"]).dt.dayofweek / 7
    # )
    df["day_of_week"] = pd.to_datetime(df["ActivityDateTime"]).dt.dayofweek

    # Cyclical encoding for month
    df["sin_month"] = np.sin(
        2 * np.pi * pd.to_datetime(df["ActivityDateTime"]).dt.month / 12
    )
    df["cos_month"] = np.cos(
        2 * np.pi * pd.to_datetime(df["ActivityDateTime"]).dt.month / 12
    )

    # Useful for indexing but will not be in the final model
    df["ActivityDateTime"] = pd.to_datetime(df["ActivityDateTime"])
    df["therapy_week"] = df.groupby("dyad")["ActivityDateTime"].transform(
        lambda x: (x - x.min()).dt.days // 7
    )

    # Drop features
    df = df.drop(
        [
            # "Diagnosis",
            # "Medication ",
            "CDI start date",
            "PDI start date",
            "PDI end date",
            "Type of medication",
            "Medication start date",
            "Week",
            "Therapy session",
            "Therapy Start",
            "Therapy End",
            "Education Status",
            "Parental Status",
            "Employment Status",
            "Pre.ECBI",
            "Pre.ECBI.Prob",
            "Post.ECBI",
            "Post.ECBI.Prob",
            "QuitStudy",
            "ParticipatingParent.Sex",
            "Parent-PhoneType",
            # Data that is only available as "real time data" (more battery use?) in Companion SDK
            # NOTE: Removing these actually improves model accuracy?
            "DurationInSeconds",  # total active time
            "DistanceInMeters",
            "ActiveKilocalories",
            "METmins",
            "METavg",
            "activity_seconds_sedentary",
            "activity_seconds_active",
            "activity_seconds_highly_active",
        ]
        # Sleep
        + [
            "awake",
            "deep",
            "light",
            "rem",
            "unmeasurable",
            # "awake_T-1",
            # "deep_T-1",
            # "light_T-1",
            # "rem_T-1",
            # "unmeasurable_T-1",
            "awake_T-2",
            "deep_T-2",
            "light_T-2",
            "rem_T-2",
            "unmeasurable_T-2",
            "awake_T-3",
            "deep_T-3",
            "light_T-3",
            "rem_T-3",
            "unmeasurable_T-3",
            "awake_T-4",
            "deep_T-4",
            "light_T-4",
            "rem_T-4",
            "unmeasurable_T-4",
        ]
        # moving window stats
        + [
            # "hr_moving_avg_10m",
            # "hr_moving_std_10m",
            # "hr_moving_min_10m",
            # "hr_moving_max_10m",
            "hr_moving_avg_30m",
            "hr_moving_std_30m",
            "hr_moving_min_30m",
            "hr_moving_max_30m",
            "hr_moving_avg_60m",
            "hr_moving_std_60m",
            "hr_moving_min_60m",
            "hr_moving_max_60m",
        ],
        axis=1,
    )
    df = df.drop([col for col in df.columns if col.startswith("hr-prev")], axis=1)

    def yn_to_bool(df):
        """
        Convert columns with 'Y'/'N' strings to boolean True/False.
        """
        for col in df.columns:
            if df[col].nunique() == 2 and set(df[col].dropna().unique()) == {"Y", "N"}:
                df[col] = df[col].map({"Y": True, "N": False})
        return df

    df = yn_to_bool(df)

    # Convert categorical columns to dummy variables
    df = pd.get_dummies(df, drop_first=True)

    return df


def prep_X_y(df: pd.DataFrame, response_column: str) -> tuple[pd.DataFrame, pd.Series]:
    X = df.drop(
        [
            "ActivityDateTime",
            "tantrum_within_60m",
            "tantrum_within_45m",
            "tantrum_within_30m",
            "tantrum_within_15m",
            # Useful for indexing
            "Arm_Sham",
            "dyad",
            "therapy_week",
        ],
        axis=1,
    )
    y = df[response_column].astype(int)
    return X, y

# %%
sorted_dyads_df = dyads_df.sort_values(
    by="ActivityDateTime", key=lambda x: pd.to_datetime(x)
)
cleaned_dyads_df = clean_data(sorted_dyads_df)

df_train = cleaned_dyads_df[cleaned_dyads_df["Arm_Sham"]]
# df_train, df_val = train_test_split(df_train, test_size=0.2, shuffle=False)
df_test = cleaned_dyads_df[~cleaned_dyads_df["Arm_Sham"]]
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/1392927669.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])

# %%
from sklearn.base import BaseEstimator


class HrModel(BaseEstimator):
    def fit(self, X, y):
        return self

    def predict(self, X):
        mean_hr = X["hr_moving_avg_10m"]
        return (mean_hr > 80) & (mean_hr < 129)

    def predict_proba(self, X):
        preds = self.predict(X)
        proba = np.zeros((len(X), 2))
        proba[:, 1] = preds.astype(float)
        proba[:, 0] = 1 - proba[:, 1]
        return proba

# %%
cleaned_dyads_df = clean_data(dyads_df)

df_train = cleaned_dyads_df[cleaned_dyads_df["Arm_Sham"]]
df_test = cleaned_dyads_df[~cleaned_dyads_df["Arm_Sham"]]
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/1392927669.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])

# %%
from flaml import AutoML
from sklearn.model_selection import TimeSeriesSplit

automl = AutoML()


automl_settings = {
    "time_budget": 15,  # seconds
    # "train_time_limit": 1,  # seconds
    "task": "classification",
    "metric": "log_loss",
    "estimator_list": ["xgboost"],
    # "split_type": time_series_split,
    "early_stop": True,
}


X_train, y_train = prep_X_y(df_train, "tantrum_within_60m")
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)
print("Best config:", automl.best_config)
# Out:
# [flaml.automl.logger: 12-19 09:50:29] {1752} INFO - task = classification
# [flaml.automl.logger: 12-19 09:50:29] {1763} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-19 09:50:29] {1862} INFO - Minimizing error metric: log_loss
# [flaml.automl.logger: 12-19 09:50:29] {1979} INFO - List of ML learners in AutoML Run: ['xgboost']
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2417} INFO - Estimated sufficient time budget=3090s. Estimated necessary time budget=3s.
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.7s,	estimator xgboost's best error=0.0254,	best estimator xgboost's best error=0.0254
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 1, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.7s,	estimator xgboost's best error=0.0254,	best estimator xgboost's best error=0.0254
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.7s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.7s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.7s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0252,	best estimator xgboost's best error=0.0252
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0243,	best estimator xgboost's best error=0.0243
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0243,	best estimator xgboost's best error=0.0243
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0243,	best estimator xgboost's best error=0.0243
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 1.0s,	estimator xgboost's best error=0.0243,	best estimator xgboost's best error=0.0243
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 1.0s,	estimator xgboost's best error=0.0243,	best estimator xgboost's best error=0.0243
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 1.1s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:29] {2466} INFO -  at 1.1s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-19 09:50:29] {2282} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:30] {2466} INFO -  at 1.3s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-19 09:50:30] {2282} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:30] {2466} INFO -  at 1.3s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-19 09:50:30] {2282} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:30] {2466} INFO -  at 1.5s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-19 09:50:30] {2282} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:30] {2466} INFO -  at 1.6s,	estimator xgboost's best error=0.0224,	best estimator xgboost's best error=0.0224
# [flaml.automl.logger: 12-19 09:50:30] {2282} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:30] {2466} INFO -  at 1.6s,	estimator xgboost's best error=0.0224,	best estimator xgboost's best error=0.0224
# [flaml.automl.logger: 12-19 09:50:30] {2282} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:31] {2466} INFO -  at 2.4s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:31] {2282} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:31] {2466} INFO -  at 2.8s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:31] {2282} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:32] {2466} INFO -  at 3.7s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:32] {2282} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:33] {2466} INFO -  at 4.2s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:33] {2282} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:33] {2466} INFO -  at 5.0s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:33] {2282} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:34] {2466} INFO -  at 5.1s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:34] {2282} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:35] {2466} INFO -  at 6.1s,	estimator xgboost's best error=0.0202,	best estimator xgboost's best error=0.0202
# [flaml.automl.logger: 12-19 09:50:35] {2282} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:36] {2466} INFO -  at 7.1s,	estimator xgboost's best error=0.0171,	best estimator xgboost's best error=0.0171
# [flaml.automl.logger: 12-19 09:50:36] {2282} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:36] {2466} INFO -  at 7.7s,	estimator xgboost's best error=0.0171,	best estimator xgboost's best error=0.0171
# [flaml.automl.logger: 12-19 09:50:36] {2282} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:38] {2466} INFO -  at 9.7s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-19 09:50:38] {2282} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:38] {2466} INFO -  at 10.1s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-19 09:50:38] {2282} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 12-19 09:50:43] {2466} INFO -  at 15.0s,	estimator xgboost's best error=0.0153,	best estimator xgboost's best error=0.0153
# [flaml.automl.logger: 12-19 09:50:54] {2724} INFO - retrain xgboost for 10.6s
# [flaml.automl.logger: 12-19 09:50:54] {2727} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=1.0, colsample_bynode=None,
#               colsample_bytree=np.float64(0.936156428767855), device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None,
#               learning_rate=np.float64(0.07345482042188167), max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=72,
#               min_child_weight=np.float64(1.8570342670499242), missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=574,
#               n_jobs=-1, num_parallel_tree=None, ...)
# [flaml.automl.logger: 12-19 09:50:54] {2009} INFO - fit succeeded
# [flaml.automl.logger: 12-19 09:50:54] {2010} INFO - Time taken to find the best model: 14.95747709274292
# Best config: {'n_estimators': 574, 'max_leaves': 72, 'min_child_weight': np.float64(1.8570342670499242), 'learning_rate': np.float64(0.07345482042188167), 'subsample': np.float64(0.8958108777182552), 'colsample_bylevel': 1.0, 'colsample_bytree': np.float64(0.936156428767855), 'reg_alpha': np.float64(0.006136131943399483), 'reg_lambda': np.float64(5.8322103409698505)}

# %% [markdown]
# -   Task = predict tantrum within 60m
# -   Test = 15m, 30m, 60m period

# %%
from sklearn.metrics import roc_auc_score
from sklearn.dummy import DummyClassifier

positive_model = DummyClassifier(strategy="constant", constant=1).fit(X_train, y_train)
hr_model = y_hat_hr = HrModel()
model = automl

df_test_60m = df_test[df_test["ActivityDateTime"].dt.minute.isin([0])]
df_test_30m = df_test[df_test["ActivityDateTime"].dt.minute.isin([0, 30])]

for label, df in [
    ("15m", df_test),
    ("30m", df_test_30m),
    ("60m", df_test_60m),
]:
    print(f"Evaluating for prediction frequency: {label}")
    X_test, y_test = prep_X_y(df, "tantrum_within_60m")

    y_hat_positive = positive_model.predict(X_test)
    print(
        f"Positive Model (Control) ROC-AUC: {roc_auc_score(y_test, y_hat_positive):.4f}"
    )

    y_hat_hr = hr_model.predict_proba(X_test)
    print(f"HR Model ROC-AUC: {roc_auc_score(y_test, y_hat_hr[:, 1]):.4f}")

    y_hat = model.predict_proba(X_test)
    print(f"XGB ROC-AUC: {roc_auc_score(y_test, y_hat[:, 1]):.4f}")
    print()
# Out:
# Evaluating for prediction frequency: 15m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5220
# XGB ROC-AUC: 0.6050
#
# Evaluating for prediction frequency: 30m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5268
# XGB ROC-AUC: 0.6143
#
# Evaluating for prediction frequency: 60m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5148
# XGB ROC-AUC: 0.6179

# %% [markdown]
# Now, fix frequency at 15m and test 15m, 30m, 60m lookahead windows

# %%
for window in ["15m", "30m", "60m"]:
    automl = AutoML()
    X_train, y_train = prep_X_y(df_train, f"tantrum_within_{window}")
    automl.fit(X_train=X_train, y_train=y_train, verbose=False, **automl_settings)

    print(f"Evaluating for lookahead window: {window}")
    X_test, y_test = prep_X_y(df_test, response_column=f"tantrum_within_{window}")
    print(f"Total positive samples: {y_test.sum()} out of {len(y_test)}")

    y_hat = model.predict_proba(X_test)
    y_hat_positive = positive_model.predict(X_test)
    y_hat_hr = hr_model.predict_proba(X_test)
    y_hat = model.predict_proba(X_test)

    print(
        f"Positive Model (Control) ROC-AUC: {roc_auc_score(y_test, y_hat_positive):.4f}"
    )
    print(f"HR Model ROC-AUC: {roc_auc_score(y_test, y_hat_hr[:, 1]):.4f}")
    print(f"XGB ROC-AUC: {roc_auc_score(y_test, y_hat[:, 1]):.4f}")
    print()
# Out:
# Evaluating for lookahead window: 15m
# Total positive samples: 159 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5260
# XGB ROC-AUC: 0.6139
#
# Evaluating for lookahead window: 30m
# Total positive samples: 313 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5249
# XGB ROC-AUC: 0.6040
#
# Evaluating for lookahead window: 60m
# Total positive samples: 612 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5220
# XGB ROC-AUC: 0.6050

# %%
import shap
from xgboost import XGBClassifier

# Fit the model if not already fitted

window = "15m"
X_train, y_train = prep_X_y(df_train, f"tantrum_within_{window}")
X_test, y_test = prep_X_y(df_test, response_column=f"tantrum_within_{window}")
model = XGBClassifier()
model.fit(X_train, y_train)

# Create SHAP explainer
explainer = shap.Explainer(model)
shap_values = explainer(X_test)

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values, max_display=20)
