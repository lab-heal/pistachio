# %% [markdown]
# TODO
#
# -   weekly performance, only show best model, weeks 0 to 20
# -   run variations of prediction window (lookahead) + frequency, plot of sensitivity by frequency/lookahead
# -   sensitivity + specificity + AUC+ROC
# -   do weekly versions + trendline, not cum
# -   for manuscript -- use terms e.g., "scheduled retraining", "closed loop"
# -   why even do online learning -- capture "in situ" context, don't simply apply historical model to new cohort
# -   experiment with oversampling recent data (or sample weighting, focus on the positive observations)
#     -   look into regret minimization algos

# %%
from pathlib import Path

import numpy as np
import pandas as pd

DATA_DIR = Path("./pistachio_1_data")
dyads_df = pd.read_csv(DATA_DIR / "all_dyads.csv")
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/2033846779.py:7: DtypeWarning: Columns (47,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   dyads_df = pd.read_csv(DATA_DIR / "all_dyads.csv")

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    df["therapy_length_days"] = (
        pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])
    ).dt.days

    df["day_of_week"] = pd.to_datetime(df["ActivityDateTime"]).dt.dayofweek
    df["month"] = pd.to_datetime(df["ActivityDateTime"]).dt.month

    df["ActivityDateTime"] = pd.to_datetime(df["ActivityDateTime"])
    df["therapy_week"] = df.groupby("dyad")["ActivityDateTime"].transform(
        lambda x: (x - x.min()).dt.days // 7
    )

    # Select features
    df = df.drop(
        [
            "DurationInSeconds",  # total active time
            "Diagnosis",
            "CDI start date",
            "PDI start date",
            "PDI end date",
            # "Medication ",
            "Type of medication",
            "Medication start date",
            "Week",
            "Therapy session",
            "Therapy Start",
            "Therapy End",
            "Education Status",
            "Parental Status",
            "Pre.ECBI",
            "Pre.ECBI.Prob",
            "Post.ECBI",
            "Post.ECBI.Prob",
            "QuitStudy",
            "Employment Status",
            "ParticipatingParent.Sex",
            "Parent-PhoneType",
            # Data that is only available as "real time data" (more battery use?) in Companion SDK
            # NOTE: Removing these actually improves model accuracy?
            "DistanceInMeters",
            "ActiveKilocalories",
            "METmins",
            "METavg",
            "activity_seconds_sedentary",
            "activity_seconds_active",
            "activity_seconds_highly_active",
        ]
        # Sleep
        + [
            "awake",
            "deep",
            "light",
            "rem",
            "unmeasurable",
            # "awake_T-1",
            # "deep_T-1",
            # "light_T-1",
            # "rem_T-1",
            # "unmeasurable_T-1",
            "awake_T-2",
            "deep_T-2",
            "light_T-2",
            "rem_T-2",
            "unmeasurable_T-2",
            "awake_T-3",
            "deep_T-3",
            "light_T-3",
            "rem_T-3",
            "unmeasurable_T-3",
            "awake_T-4",
            "deep_T-4",
            "light_T-4",
            "rem_T-4",
            "unmeasurable_T-4",
        ]
        # moving window stats
        + [
            # "hr_moving_avg_10m",
            # "hr_moving_std_10m",
            # "hr_moving_min_10m",
            # "hr_moving_max_10m",
            "hr_moving_avg_30m",
            "hr_moving_std_30m",
            "hr_moving_min_30m",
            "hr_moving_max_30m",
            "hr_moving_avg_60m",
            "hr_moving_std_60m",
            "hr_moving_min_60m",
            "hr_moving_max_60m",
        ],
        axis=1,
    )
    df = df.drop([col for col in df.columns if col.startswith("hr-prev")], axis=1)

    def yn_to_bool(df):
        """
        Convert columns with 'Y'/'N' strings to boolean True/False.
        """
        for col in df.columns:
            if df[col].nunique() == 2 and set(df[col].dropna().unique()) == {"Y", "N"}:
                df[col] = df[col].map({"Y": True, "N": False})
        return df

    df = yn_to_bool(df)

    # Convert categorical columns to dummy variables
    df = pd.get_dummies(df, drop_first=True)

    return df


def prep_X_y(df: pd.DataFrame, response_column: str) -> tuple[pd.DataFrame, pd.Series]:
    X = df.drop(
        [
            "ActivityDateTime",
            "tantrum_within_60m",
            "tantrum_within_45m",
            "tantrum_within_30m",
            "tantrum_within_15m",
            # Useful for indexing
            "Arm_Sham",
            "dyad",
            "therapy_week",
        ],
        axis=1,
    )
    y = df[response_column].astype(int)
    return X, y

# %%
sorted_dyads_df = dyads_df.sort_values(
    by="ActivityDateTime", key=lambda x: pd.to_datetime(x)
)
cleaned_dyads_df = clean_data(sorted_dyads_df)

df_train = cleaned_dyads_df[cleaned_dyads_df["Arm_Sham"]]
# df_train, df_val = train_test_split(df_train, test_size=0.2, shuffle=False)
df_test = cleaned_dyads_df[~cleaned_dyads_df["Arm_Sham"]]
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/2778819451.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])

# %%
from sklearn.base import BaseEstimator


class HrModel(BaseEstimator):
    def fit(self, X, y):
        return self

    def predict(self, X):
        mean_hr = X["hr_moving_avg_10m"]
        return (mean_hr > 80) & (mean_hr < 129)

    def predict_proba(self, X):
        preds = self.predict(X)
        proba = np.zeros((len(X), 2))
        proba[:, 1] = preds.astype(float)
        proba[:, 0] = 1 - proba[:, 1]
        return proba

# %%
cleaned_dyads_df = clean_data(dyads_df)

df_train = cleaned_dyads_df[cleaned_dyads_df["Arm_Sham"]]
df_test = cleaned_dyads_df[~cleaned_dyads_df["Arm_Sham"]]
# Out:
# /var/folders/3f/rygbfpzx3l7fcpbc7540q88w0000gr/T/ipykernel_88852/2778819451.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["ActivityDateTime"]) - pd.to_datetime(df["Therapy Start"])

# %%
from flaml import AutoML
from sklearn.model_selection import TimeSeriesSplit

automl = AutoML()


automl_settings = {
    "time_budget": 15,  # seconds
    # "train_time_limit": 1,  # seconds
    "task": "classification",
    "metric": "log_loss",
    "estimator_list": ["xgboost"],
    # "split_type": time_series_split,
    "early_stop": True,
}


X_train, y_train = prep_X_y(df_train, "tantrum_within_60m")
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)
print("Best config:", automl.best_config)
# Out:
# [flaml.automl.logger: 12-18 22:19:37] {1752} INFO - task = classification
# [flaml.automl.logger: 12-18 22:19:37] {1763} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-18 22:19:37] {1862} INFO - Minimizing error metric: log_loss
# [flaml.automl.logger: 12-18 22:19:37] {1979} INFO - List of ML learners in AutoML Run: ['xgboost']
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2417} INFO - Estimated sufficient time budget=4989s. Estimated necessary time budget=5s.
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 1, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0253,	best estimator xgboost's best error=0.0253
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.8s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0236,	best estimator xgboost's best error=0.0236
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 0.9s,	estimator xgboost's best error=0.0231,	best estimator xgboost's best error=0.0231
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.0s,	estimator xgboost's best error=0.0231,	best estimator xgboost's best error=0.0231
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.0s,	estimator xgboost's best error=0.0229,	best estimator xgboost's best error=0.0229
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.1s,	estimator xgboost's best error=0.0221,	best estimator xgboost's best error=0.0221
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.1s,	estimator xgboost's best error=0.0221,	best estimator xgboost's best error=0.0221
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.1s,	estimator xgboost's best error=0.0221,	best estimator xgboost's best error=0.0221
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.2s,	estimator xgboost's best error=0.0221,	best estimator xgboost's best error=0.0221
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:37] {2466} INFO -  at 1.3s,	estimator xgboost's best error=0.0221,	best estimator xgboost's best error=0.0221
# [flaml.automl.logger: 12-18 22:19:37] {2282} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:38] {2466} INFO -  at 1.4s,	estimator xgboost's best error=0.0209,	best estimator xgboost's best error=0.0209
# [flaml.automl.logger: 12-18 22:19:38] {2282} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:38] {2466} INFO -  at 1.5s,	estimator xgboost's best error=0.0209,	best estimator xgboost's best error=0.0209
# [flaml.automl.logger: 12-18 22:19:38] {2282} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:38] {2466} INFO -  at 1.8s,	estimator xgboost's best error=0.0192,	best estimator xgboost's best error=0.0192
# [flaml.automl.logger: 12-18 22:19:38] {2282} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:38] {2466} INFO -  at 1.9s,	estimator xgboost's best error=0.0192,	best estimator xgboost's best error=0.0192
# [flaml.automl.logger: 12-18 22:19:38] {2282} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:39] {2466} INFO -  at 2.6s,	estimator xgboost's best error=0.0187,	best estimator xgboost's best error=0.0187
# [flaml.automl.logger: 12-18 22:19:39] {2282} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:40] {2466} INFO -  at 3.6s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:40] {2282} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:40] {2466} INFO -  at 4.3s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:40] {2282} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:41] {2466} INFO -  at 4.8s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:41] {2282} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:42] {2466} INFO -  at 5.8s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:42] {2282} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:42] {2466} INFO -  at 6.0s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:42] {2282} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:44] {2466} INFO -  at 7.5s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:44] {2282} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:44] {2466} INFO -  at 8.0s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:44] {2282} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:45] {2466} INFO -  at 8.6s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:45] {2282} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:45] {2466} INFO -  at 8.9s,	estimator xgboost's best error=0.0157,	best estimator xgboost's best error=0.0157
# [flaml.automl.logger: 12-18 22:19:45] {2282} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 12-18 22:19:48] {2466} INFO -  at 12.0s,	estimator xgboost's best error=0.0150,	best estimator xgboost's best error=0.0150
# [flaml.automl.logger: 12-18 22:19:51] {2724} INFO - retrain xgboost for 3.0s
# [flaml.automl.logger: 12-18 22:19:51] {2727} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=np.float64(0.8677023616878445),
#               colsample_bynode=None,
#               colsample_bytree=np.float64(0.8704740385078042), device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None,
#               learning_rate=np.float64(0.10758793301399036), max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=100,
#               min_child_weight=np.float64(7.213415563487486), missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=183,
#               n_jobs=-1, num_parallel_tree=None, ...)
# [flaml.automl.logger: 12-18 22:19:51] {2009} INFO - fit succeeded
# [flaml.automl.logger: 12-18 22:19:51] {2010} INFO - Time taken to find the best model: 12.04266905784607
# Best config: {'n_estimators': 183, 'max_leaves': 100, 'min_child_weight': np.float64(7.213415563487486), 'learning_rate': np.float64(0.10758793301399036), 'subsample': np.float64(0.8653404795511568), 'colsample_bylevel': np.float64(0.8677023616878445), 'colsample_bytree': np.float64(0.8704740385078042), 'reg_alpha': np.float64(0.13388901495622793), 'reg_lambda': np.float64(0.5682226763801638)}

# %% [markdown]
# -   Task = predict tantrum within 60m
# -   Test = 15m, 30m, 60m period

# %%
from sklearn.metrics import roc_auc_score
from sklearn.dummy import DummyClassifier

positive_model = DummyClassifier(strategy="constant", constant=1).fit(X_train, y_train)
hr_model = y_hat_hr = HrModel()
model = automl

df_test_60m = df_test[df_test["ActivityDateTime"].dt.minute.isin([0])]
df_test_30m = df_test[df_test["ActivityDateTime"].dt.minute.isin([0, 30])]

for label, df in [
    ("15m", df_test),
    ("30m", df_test_30m),
    ("60m", df_test_60m),
]:
    print(f"Evaluating for prediction frequency: {label}")
    X_test, y_test = prep_X_y(df, "tantrum_within_60m")

    y_hat_positive = positive_model.predict(X_test)
    print(
        f"Positive Model (Control) ROC-AUC: {roc_auc_score(y_test, y_hat_positive):.4f}"
    )

    y_hat_hr = hr_model.predict_proba(X_test)
    print(f"HR Model ROC-AUC: {roc_auc_score(y_test, y_hat_hr[:, 1]):.4f}")

    y_hat = model.predict_proba(X_test)
    print(f"XGB ROC-AUC: {roc_auc_score(y_test, y_hat[:, 1]):.4f}")
    print()
# Out:
# Evaluating for prediction frequency: 15m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5220
# XGB ROC-AUC: 0.5856
#
# Evaluating for prediction frequency: 30m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5268
# XGB ROC-AUC: 0.5941
#
# Evaluating for prediction frequency: 60m
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5148
# XGB ROC-AUC: 0.5928

# %% [markdown]
# Now, fix frequency at 15m and test 15m, 30m, 60m lookahead windows

# %%
for window in ["15m", "30m", "60m"]:
    automl = AutoML()
    X_train, y_train = prep_X_y(df_train, f"tantrum_within_{window}")
    automl.fit(X_train=X_train, y_train=y_train, verbose=False, **automl_settings)

    print(f"Evaluating for lookahead window: {window}")
    X_test, y_test = prep_X_y(df_test, response_column=f"tantrum_within_{window}")
    print(f"Total positive samples: {y_test.sum()} out of {len(y_test)}")

    y_hat = model.predict_proba(X_test)
    y_hat_positive = positive_model.predict(X_test)
    y_hat_hr = hr_model.predict_proba(X_test)
    y_hat = model.predict_proba(X_test)

    print(
        f"Positive Model (Control) ROC-AUC: {roc_auc_score(y_test, y_hat_positive):.4f}"
    )
    print(f"HR Model ROC-AUC: {roc_auc_score(y_test, y_hat_hr[:, 1]):.4f}")
    print(f"XGB ROC-AUC: {roc_auc_score(y_test, y_hat[:, 1]):.4f}")
    print()
# Out:
# Evaluating for lookahead window: 15m
# Total positive samples: 159 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5260
# XGB ROC-AUC: 0.5968
#
# Evaluating for lookahead window: 30m
# Total positive samples: 313 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5249
# XGB ROC-AUC: 0.5868
#
# Evaluating for lookahead window: 60m
# Total positive samples: 612 out of 255981
# Positive Model (Control) ROC-AUC: 0.5000
# HR Model ROC-AUC: 0.5220
# XGB ROC-AUC: 0.5856

# %%
import shap
from xgboost import XGBClassifier

# Fit the model if not already fitted

X_train, y_train = prep_X_y(df_train, f"tantrum_within_{window}")
X_test, y_test = prep_X_y(df_test, response_column=f"tantrum_within_{window}")
model = XGBClassifier()
model.fit(X_train, y_train)

# Create SHAP explainer
explainer = shap.Explainer(model)
shap_values = explainer(X_test)
# Out:
# Found a NULL input array in _cext_dense_tree_update_weights!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 12
#       9 model.fit(X_train, y_train)
#      11 # Create SHAP explainer
# ---> 12 explainer = shap.TreeExplainer(model, X_train)
#      13 shap_values = explainer(X_test)
#
# File ~/projects/pistachio/.venv/lib/python3.13/site-packages/shap/explainers/_tree.py:279, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, link, linearize_link)
#     277 self.feature_perturbation = feature_perturbation
#     278 self.expected_value = None
# --> 279 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     280 self.model_output = model_output
#     281 # self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#     282
#     283 # check for unsupported combinations of feature_perturbation and model_outputs
#
# File ~/projects/pistachio/.venv/lib/python3.13/site-packages/shap/explainers/_tree.py:1262, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#    1260 self.input_dtype = np.float32
#    1261 self.original_model = model.get_booster()
# -> 1262 self._set_xgboost_model_attributes(
#    1263     data,
#    1264     data_missing,
#    1265     objective_name_map,
#    1266     tree_output_name_map,
#    1267 )
#    1269 if self.model_output == "predict_proba":
#    1270     if self.num_stacked_models == 1:
#    1271         # with predict_proba we need to double the outputs to match
#
# File ~/projects/pistachio/.venv/lib/python3.13/site-packages/shap/explainers/_tree.py:1509, in TreeEnsemble._set_xgboost_model_attributes(self, data, data_missing, objective_name_map, tree_output_name_map)
#    1506 self.model_type = "xgboost"
#    1507 loader = XGBTreeModelLoader(self.original_model)
# -> 1509 self.trees = loader.get_trees(data=data, data_missing=data_missing)
#    1510 self.base_offset = loader.base_score
#    1511 self.objective = objective_name_map.get(loader.name_obj, None)
#
# File ~/projects/pistachio/.venv/lib/python3.13/site-packages/shap/explainers/_tree.py:2284, in XGBTreeModelLoader.get_trees(self, data, data_missing)
#    2273 for i in range(self.num_trees):
#    2274     info = {
#    2275         "children_left": self.node_cleft[i],
#    2276         "children_right": self.node_cright[i],
#    (...)   2282         "node_sample_weight": self.sum_hess[i],
#    2283     }
# -> 2284     trees.append(SingleTree(info, data=data, data_missing=data_missing))
#    2285 return trees
#
# File ~/projects/pistachio/.venv/lib/python3.13/site-packages/shap/explainers/_tree.py:2000, in SingleTree.__init__(self, tree, normalize, scaling, data, data_missing)
#    1998 if data is not None and data_missing is not None:
#    1999     self.node_sample_weight.fill(0.0)
# -> 2000     _cext.dense_tree_update_weights(
#    2001         self.children_left,
#    2002         self.children_right,
#    2003         self.children_default,
#    2004         self.features,
#    2005         self.thresholds,
#    2006         self.threshold_types,
#    2007         self.values,
#    2008         1,
#    2009         self.node_sample_weight,
#    2010         data,
#    2011         data_missing,
#    2012     )
#    2014 # we compute the expectations to make sure they follow the SHAP logic
#    2015 self.max_depth = _cext.compute_expectations(
#    2016     self.children_left, self.children_right, self.node_sample_weight, self.values
#    2017 )
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values, max_display=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 shap.plots.beeswarm(shap_values, max_display=20)
#
# NameError: name 'shap' is not defined

# %%
# Absolute max value highlights features that have infrequent but strong impacts
shap.plots.bar(shap_values.abs.max(0))

# %%
shap.plots.beeswarm(shap_values.abs, color="shap_red")
